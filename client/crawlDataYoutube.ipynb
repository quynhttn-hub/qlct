# %%
pip install google-api-python-client
# Out:
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached google_api_core-2.19.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.8 MB 2.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/11.8 MB 3.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/11.8 MB 3.5 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.8 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/11.8 MB 4.7 MB/s eta 0:00:03
# ...

# %%
from googleapiclient.discovery import build

# Thay thế bằng API key của bạn
api_key = 'AIzaSyBIvXUMdQ0UlXnsRtA2FS4s2IRYqykoXLI'
max_results = 10
keyword = 'quản lý chi tiêu'

# Tạo một YouTube API client
youtube = build('youtube', 'v3', developerKey=api_key)

# Hàm tìm kiếm video phổ biến theo từ khóa
def search_videos_by_keyword(keyword, max_results):
    request = youtube.search().list(
        q=keyword,
        part='snippet',
        type='video',
        order='viewCount',
        maxResults=max_results
    )
    response = request.execute()

    video_urls = []
    for item in response['items']:
        video_id = item['id']['videoId']
        video_embed_url = f'https://www.youtube.com/embed/{video_id}'
        title = item['snippet']['title']
        description = item['snippet']['description']
        print(f'Title: {title}')
        print(f'Description: {description}')
        print(f'Embed URL: {video_embed_url}\n')
        video_urls.append({"video_embed_url": video_embed_url, "title": title})

    return video_urls
# 
# Gọi hàm tìm kiếm video
video_urls = search_videos_by_keyword(keyword, max_results)
# Out:
# Title: 🔴 Công thức Quản Lý Tiền Bạc HAY XUẤT SẮC và THÔNG MINH
# Description: Trở thành fanVIP: https://www.youtube.com/channel/UCkgjUHB8sdWbmdp39swMrTg/join - Đăng ký theo dõi kênh: ...
# Embed URL: https://www.youtube.com/embed/J71G4HGJiqA
#
# Title: 10 Cách Giữ Tiền Cho Người Hay Hết Tiền
# Description: Trở thành fanVIP: https://www.youtube.com/channel/UCkgjUHB8sdWbmdp39swMrTg/join Các chương: 0:00 Zô thôi 0:35 Cách 1 ...
# Embed URL: https://www.youtube.com/embed/RImB8QAR8NU
#
# Title: App quản lý chi tiêu tự động chia quỹ, không cần ghi chép | Ngân hàng số Timo
# Description: Bạn thường xuyên bị "cháy túi" vào cuối tháng nhưng lại không biết tiền của mình đã chi vào đâu. Bạn cũng từng sử dụng nhiều ...
# Embed URL: https://www.youtube.com/embed/gnTmq1h8qfw
#
# Title: 9 sai lầm về tài chính cá nhân khi 20-30 tuổi
# Description: Cách đây vài hôm tôi có chia sẻ câu chuyện của Mark, cậu trợ lý của tôi. Cậu là người mà tôi đã có dịp dẫn dắt gần như là trọn ...
# ...

# %%
import json

# %%
with open("video_data.json", "w", encoding='utf-8') as f:
    json.dump(video_urls, f, ensure_ascii=False, indent=4)

# %%
video_urls
# Out:
# [[{'https://www.youtube.com/embed/J71G4HGJiqA',
#    '🔴 Công thức Quản Lý Tiền Bạc HAY XUẤT SẮC và THÔNG MINH'}],
#  [{'Quản lý tài chính cá nhân | Leo Cường',
#    'https://www.youtube.com/embed/8m-gH2MIiao'}],
#  [{'9 sai lầm về tài chính cá nhân khi 20-30 tuổi',
#    'https://www.youtube.com/embed/2EyGqvZrbyc'}],
#  [{'9 sai lầm tài chính cá nhân khi 30-40 tuổi',
#    'https://www.youtube.com/embed/HjuGeuQwNIs'}],
#  [{'3 Cách Quản Lý Tiền Bạc của Người Giàu - Biết Sớm Giàu Sớm',
#    'https://www.youtube.com/embed/rnYFQSnXOTA'}],
#  [{'Lương 8 triệu/tháng, làm sao để MUA NHÀ trong 2 NĂM? | Nguyễn Hữu Trí',
#    'https://www.youtube.com/embed/RQjPVJDhrcg'}],
#  [{'Cô Gái Bị Ép Cưới Lão Già 80 Được Tổng Tài Giải Cứu, Không Ngờ Cô là Người Vợ Mất tích Anh tìm kiếm',
#    'https://www.youtube.com/embed/wxZ3c4jfCro'}],
#  [{'Kho Sách Nói Channel | Cách Người Do Thái Quản Lý Tiền Và Tài Sản',
#    'https://www.youtube.com/embed/UFP8ZNgN-Ok'}],
# ...
